# %% [markdown]
# ## Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import random
import os
import numpy as np

from matplotlib import pyplot as plt

# %%
class CFG:
    SEED = 42

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(CFG.SEED) # Seed 고정

# %% [markdown]
# ## Data Load

# %%
best_sub = pd.read_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_18.csv')

# %%
X_train = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/train.csv')

# %%
y_train = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/train.csv')['class']

# %%
X_train = X_train.iloc[:,:-1]

# %%
X_test = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/test.csv')

# %%
DF_all = pd.concat([X_train,X_test])

# %%
index = DF_all['id']

# %%
DF_all = DF_all.iloc[:,4:]

# %%
from sklearn import preprocessing

# %%
class_le = preprocessing.LabelEncoder()
snp_le = preprocessing.LabelEncoder()
snp_col = [f'SNP_{str(x).zfill(2)}' for x in range(1,16)]

# %%
snp_data = []
for col in snp_col:
    snp_data += list(DF_all[col].values)

# %%
for col in DF_all.columns:
    if col in snp_col:
        DF_all[col] = snp_le.fit_transform(DF_all[col])

# %%
DF_all = DF_all.reset_index(drop=True)

# %%
index = pd.DataFrame(index).reset_index(drop=True)

# %%
index.query('id == "TEST_019"')
# Out:
#            id
# 281  TEST_019

# %%
index.loc[[355]]
# Out:
#            id
# 355  TEST_093

# %%
DF_all.transpose().corr().loc[[281]].T.sort_values(by=281, ascending=False).head(30)
# Out:
#           281
# 281  1.000000
# 151  0.887443
# 23   0.824787
# 40   0.812350
# 175  0.808383
# 93   0.804181
# 361  0.801580
# 384  0.790631
# 20   0.783054
# 307  0.783054
# 12   0.778829
# 208  0.778829
# 103  0.778829
# 407  0.778829
# 144  0.769944
# 121  0.766292
# 247  0.766292
# 139  0.758361
# 125  0.758361
# 214  0.758361
# 9    0.756254
# 242  0.755856
# 343  0.740541
# 42   0.736609
# 169  0.734723
# 128  0.731194
# 415  0.731074
# 140  0.731074
# 78   0.712575
# 300  0.712575

# %%
best_sub.loc[[19]]
# Out:
#           id class
# 19  TEST_019     C

# %%
y_train.loc[[93]]
# Out:
# 93    C
# Name: class, dtype: object

# %%
C 0.887443
B 0.824787
B 0.812350
C 0.808383
C 0.804181

# %%
all_models_score = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/models_score.csv')
submit = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/all_submit.csv')

# %% [markdown]
# ## Emsemble

# %%
submit_00 = submit.copy()

# %%
submit_00[['ExtraTreesClassifier', 'Perceptron', 'RidgeClassifierCV', 'RidgeClassifier', 'MLPClassifier', 'SVC', 'DecisionTreeClassifier', 'SGDClassifier', 'BaggingClassifier']]
# Out:
#     ExtraTreesClassifier Perceptron RidgeClassifierCV RidgeClassifier  \
# 0                      A          A                 A               A
# 1                      B          B                 B               B
# 2                      C          C                 C               C
# 3                      C          C                 C               C
# 4                      A          A                 A               A
# ..                   ...        ...               ...             ...
# 170                    B          B                 B               B
# 171                    C          C                 C               C
# 172                    C          C                 C               C
# 173                    B          B                 B               B
# 174                    B          B                 B               B
#
#     MLPClassifier SVC DecisionTreeClassifier SGDClassifier BaggingClassifier
# ...

# %%
Last_submmit_00 = pd.DataFrame(submit['id'])
Last_submmit_00['class'] = submit_00.agg(pd.Series.mode,axis=1)

# %%
all_models_score
# Out:
#                         Unnamed: 0  feature_per    cv_scr
# 0             ExtraTreesClassifier           92  0.975208
# 1                       Perceptron           55  0.971353
# 2                RidgeClassifierCV           62  0.967783
# 3                  RidgeClassifier           62  0.967783
# 4                    MLPClassifier           53  0.967579
# 5                              SVC           61  0.964134
# 6           DecisionTreeClassifier           44  0.964134
# 7                    SGDClassifier           66  0.964060
# 8                BaggingClassifier           48  0.964031
# 9                        LinearSVC           51  0.960716
# 10      GradientBoostingClassifier           48  0.960671
# 11            LogisticRegressionCV           51  0.960601
# 12     PassiveAggressiveClassifier           20  0.960388
# 13          RandomForestClassifier           69  0.960363
# 14       GaussianProcessClassifier           25  0.960339
# ...

# %%
submit_add = submit.drop(labels=['id','DummyClassifier','LinearDiscriminantAnalysis'],axis=1)
submit_add['sum'] = submit_add.sum(axis=1)
submit_add['A'] = submit_add['sum'].apply(lambda x: x.count('A') )
submit_add['B'] = submit_add['sum'].apply(lambda x: x.count('B') )
submit_add['C'] = submit_add['sum'].apply(lambda x: x.count('C') )
submit_add = submit_add.iloc[:,-3:]
submit_add['rate'] = submit_add.agg(pd.Series.max,axis=1)/submit_add.agg(pd.Series.sum,axis=1)

# %%
ABC = submit_add.sort_values(by = 'rate', ascending=True)

# %%
ABC
# Out:
#       A   B   C      rate
# 162   0  15  16  0.516129
# 117   0  18  13  0.580645
# 126   0  19  12  0.612903
# 90    0  21  10  0.677419
# 60    9   0  22  0.709677
# ..   ..  ..  ..       ...
# 69    0  31   0  1.000000
# 71    0  31   0  1.000000
# 72   31   0   0  1.000000
# 74    0   0  31  1.000000
# 87    0  31   0  1.000000
#
# [175 rows x 4 columns]

# %%
ABC.head(20)
# Out:
#      A   B   C      rate
# 162  0  15  16  0.516129
# 117  0  18  13  0.580645
# 126  0  19  12  0.612903
# 90   0  21  10  0.677419
# 60   9   0  22  0.709677
# 19   0  23   8  0.741935
# 119  0   7  24  0.774194
# 5    0  25   6  0.806452
# 35   0  26   5  0.838710
# 21   0  26   5  0.838710
# 12   0  26   5  0.838710
# 49   0   5  26  0.838710
# 110  0   4  27  0.870968
# 83   0  27   4  0.870968
# 29   0  27   4  0.870968
# 64   0   4  27  0.870968
# 84   0  27   4  0.870968
# 145  0  28   3  0.903226
# 92   0   3  28  0.903226
# 132  0  28   3  0.903226

# %%
submit_copy = submit.copy()
submit_copy = submit_copy.iloc[:,1:]

# %%
submit_copy.iloc[[162,117,126,90,60,19,119,5],:15]
# Out:
#     AdaBoostClassifier BaggingClassifier DecisionTreeClassifier  \
# 162                  C                 B                      C
# 117                  B                 B                      B
# 126                  B                 B                      B
# 90                   C                 B                      C
# 60                   A                 A                      A
# 19                   C                 B                      C
# 119                  C                 C                      C
# 5                    C                 B                      B
#
#     DummyClassifier ExtraTreeClassifier ExtraTreesClassifier  \
# 162               C                   C                    C
# 117               C                   B                    B
# 126               B                   B                    C
# 90                A                   B                    C
# 60                A                   C                    C
# ...

# %%
submit_copy.iloc[[162,117,126,90,60,19,119,5],15:]
# Out:
#     RidgeClassifier SGDClassifier SVC LogisticRegression LogisticRegressionCV  \
# 162               B             B   C                  B                    B
# 117               C             C   B                  C                    C
# 126               C             C   B                  B                    B
# 90                C             B   C                  B                    B
# 60                A             A   C                  C                    C
# 19                B             B   B                  B                    B
# 119               C             C   C                  C                    C
# 5                 B             B   B                  B                    B
#
#     BernoulliNB CalibratedClassifierCV GaussianNB KNeighborsClassifier  \
# 162           C                      B          B                    B
# 117           B                      C          C                    B
# ...

# %%
# Last_submmit.to_csv('`/content/drive/MyDrive/유전체공모전/submissions/Fine_01.csv', index=False)

# %% [markdown]
# ## Submission_01

# %%
submit_01 = submit.copy()

# %%
submit_01 = submit_01.drop(labels=['id','DummyClassifier','LinearDiscriminantAnalysis'],axis=1)

# %%
Last_submmit_01 = pd.DataFrame(submit['id'])
Last_submmit_01['class'] = submit_01.agg(pd.Series.mode,axis=1)

# %%
# Last_submmit_01.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_01.csv', index=False)

# %% [markdown]
# ## Submission_02

# %%
submit_02 = submit.copy()

# %%
submit_02 = submit_02.drop(labels=['id','DummyClassifier','LinearDiscriminantAnalysis','AdaBoostClassifier','DecisionTreeClassifier'],axis=1)

# %%
Last_submmit_02 = pd.DataFrame(submit['id'])
Last_submmit_02['class'] = submit_02.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_01.compare(Last_submmit_02)
# 잘못분류되었을 가능성이 높은 162번째 값 변경
# Out:
#     class
#      self other
# 162     C     B

# %%
# Last_submmit_02.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02.csv', index=False)

# %%
## 결과 0.9814285714 -> 0.9719171917로 떨어짐 : 162번 피처 정답 : C

# %% [markdown]
# ## Submission_03

# %%
submit_03 = submit.copy()

# %%
submit_03 = submit_03.drop(labels=['id','DummyClassifier','LinearDiscriminantAnalysis','BaggingClassifier', 'GradientBoostingClassifier', 'NuSVC', 'RandomForestClassifier', 'KNeighborsClassifier', 'RidgeClassifierCV'],axis=1)

# %%
Last_submmit_03 = pd.DataFrame(submit['id'])
Last_submmit_03['class'] = submit_03.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_01.compare(Last_submmit_03)
# 잘못분류되었을 가능성이 높은 117번째 값 변경
# Out:
#     class
#      self other
# 117     B     C

# %%
# Last_submmit_03.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_03.csv', index=False)

# %%
## 결과 0.9814285714 -> 0.9814285714로 유지됨 : f1_macro의 계산식때문인거같은데 사유는 잘 모르겠음

# %% [markdown]
# ## Submission_04

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
Best_sub = pd.read_csv('/content/drive/MyDrive/유전체공모전/submissions/baseline12.csv')

# %%
first = Best_sub.copy()

# %%
first['class'].compare(submit_copy['LGBMClassifier'])
# Out:
#    self other
# 5     C     B
# 19    C     B
# 66    C     B

# %%
first['class'].compare(submit_copy['AdaBoostClassifier'])
# Out:
#     self other
# 12     B     C
# 29     B     C
# 35     B     C
# 39     C     B
# 48     B     C
# 66     C     B
# 83     B     C
# 90     B     C
# 107    B     C
# 110    C     B
# 117    C     B
# 132    B     C

# %%
first['class_01'] = first['class']
first['class_02'] = first['class']
first['LGBMClassifier'] = submit_copy['LGBMClassifier']
first['LGBMClassifier_01'] = submit_copy['LGBMClassifier']
first['AdaBoostClassifier'] = submit_copy['AdaBoostClassifier']
first['AdaBoostClassifier_01'] = submit_copy['AdaBoostClassifier']
first = first.iloc[:,1:]

# %%
Last_submmit_04 = pd.DataFrame(submit['id'])
Last_submmit_04['class'] = first.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_04.compare(Best_sub)
# Out:
#    class
#     self other
# 66     B     C

# %%
# Last_submmit_04.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_04.csv', index=False)

# %%
# 0.9907850434 -> 0.9907850434 66번 피처 B로 변경에도 불구하고 성능이 같음

# %% [markdown]
# ## Submission_05

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
second = Best_sub.copy()

# %%
second['class'].compare(submit_copy['AdaBoostClassifier'])
# Out:
#     self other
# 12     B     C
# 29     B     C
# 35     B     C
# 39     C     B
# 48     B     C
# 66     C     B
# 83     B     C
# 90     B     C
# 107    B     C
# 110    C     B
# 117    C     B
# 132    B     C

# %%
second['class'].compare(submit_copy['RidgeClassifierCV'])
# Out:
#     self other
# 5      C     B
# 19     C     B
# 60     A     C
# 66     C     B
# 117    C     B
# 126    B     C
# 162    C     B

# %%
second['class_01'] = second['class']
second['class_02'] = second['class']
second['AdaBoostClassifier'] = submit_copy['AdaBoostClassifier']
second['AdaBoostClassifier_01'] = submit_copy['AdaBoostClassifier']
second['RidgeClassifierCV'] = submit_copy['RidgeClassifierCV']
second['RidgeClassifierCV_01'] = submit_copy['RidgeClassifierCV']
second = second.iloc[:,1:]

# %%
Last_submmit_05 = pd.DataFrame(submit['id'])
Last_submmit_05['class'] = second.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_05.compare(Best_sub)
# Out:
#     class
#      self other
# 66      B     C
# 117     B     C

# %%
# Last_submmit_05.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_05.csv', index=False)

# %%
# # 0.9907850434 -> 0.9907850434 66번 피처 B 변경, 117번 피처 B로 변경 했음 성능 개선 X

# %% [markdown]
# ### 의심되는 행

# %%
abcd = pd.concat([Best_sub,ABC.sort_index()],axis=1).iloc[:,1:]

# %%
abcd = abcd.sort_values(by = 'rate', ascending=False)

# %%
abcd.iloc[167:,:]
# Out:
#     class  A   B   C      rate
# 5       C  0  25   6  0.806452
# 119     C  0   7  24  0.774194
# 19      C  0  23   8  0.741935
# 60      A  9   0  22  0.709677
# 90      B  0  21  10  0.677419
# 126     B  0  19  12  0.612903
# 117     C  0  18  13  0.580645
# 162     C  0  15  16  0.516129

# %% [markdown]
# ## Submission_06

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
third = Best_sub.copy()

# %%
third['class'].compare(submit_copy['GradientBoostingClassifier'])
# Out:
#     self other
# 5      C     B
# 21     B     C
# 60     A     C
# 66     C     B
# 83     B     C
# 117    C     B
# 162    C     B

# %%
third['class'].compare(submit_copy['LGBMClassifier'])
# Out:
#    self other
# 5     C     B
# 19    C     B
# 66    C     B

# %%
third['class_01'] = third['class']
third['class_02'] = third['class']
third['GradientBoostingClassifier'] = submit_copy['GradientBoostingClassifier']
third['GradientBoostingClassifier_01'] = submit_copy['GradientBoostingClassifier']
third['LGBMClassifier'] = submit_copy['LGBMClassifier']
third['LGBMClassifier_01'] = submit_copy['LGBMClassifier']
third = third.iloc[:,1:]

# %%
Last_submmit_06 = pd.DataFrame(submit['id'])
Last_submmit_06['class'] = third.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_06.compare(Best_sub)
# Out:
#    class
#     self other
# 5      B     C
# 66     B     C

# %%
# Last_submmit_06.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_06.csv', index=False)

# %%
# 0.9907850434 -> 0.0.9814285714 66번 피처 B 변경, 5번 피처 B로 변경 했음 성능 개선 떨어짐 -> 5번은 정답이 C

# %% [markdown]
# ## Submission_07

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
fourth = Best_sub.copy()

# %%
fourth['class'].compare(submit_copy['GaussianProcessClassifier'])
# Out:
#     self other
# 19     C     B
# 60     A     C
# 66     C     B
# 117    C     B
# 119    C     B

# %%
fourth['class'].compare(submit_copy['HistGradientBoostingClassifier'])
# Out:
#     self other
# 5      C     B
# 19     C     B
# 66     C     B
# 145    B     C

# %%
fourth['class_01'] = fourth['class']
fourth['class_02'] = fourth['class']
fourth['HistGradientBoostingClassifier'] = submit_copy['HistGradientBoostingClassifier']
fourth['HistGradientBoostingClassifier_01'] = submit_copy['HistGradientBoostingClassifier']
fourth['GaussianProcessClassifier'] = submit_copy['GaussianProcessClassifier']
fourth['GaussianProcessClassifier_01'] = submit_copy['GaussianProcessClassifier']
fourth = fourth.iloc[:,1:]

# %%
Last_submmit_07 = pd.DataFrame(submit['id'])
Last_submmit_07['class'] = fourth.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_07.compare(Best_sub)
# Out:
#    class
#     self other
# 19     B     C
# 66     B     C

# %%
# Last_submmit_07.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_07.csv', index=False)

# %%
# 0.9907850434 -> 0.9907850434 66번 피처 B 변경, 19번 피처 B로 변경 했음 성능 개선 X

# %% [markdown]
# ## Submission_08

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
fifth = Best_sub.copy()

# %%
fifth['class'].compare(submit_copy['MLPClassifier'])
# Out:
#     self other
# 5      C     B
# 60     A     C
# 66     C     B
# 126    B     C

# %%
fifth['class'].compare(submit_copy['LabelSpreading'])
# Out:
#     self other
# 12     B     C
# 19     C     B
# 60     A     C
# 66     C     B
# 84     B     C
# 90     B     C
# 117    C     B
# 119    C     B
# 167    B     C

# %%
fifth['class_01'] = fifth['class']
fifth['class_02'] = fifth['class']
fifth['MLPClassifier'] = submit_copy['MLPClassifier']
fifth['MLPClassifier_01'] = submit_copy['MLPClassifier']
fifth['LabelSpreading'] = submit_copy['LabelSpreading']
fifth['LabelSpreading_01'] = submit_copy['LabelSpreading']
fifth = fifth.iloc[:,1:]

# %%
Last_submmit_08 = pd.DataFrame(submit['id'])
Last_submmit_08['class'] = fifth.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_08.compare(Best_sub)
# Out:
#    class
#     self other
# 60     C     A
# 66     B     C

# %%
# Last_submmit_08.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_08.csv', index=False)

# %%
# 0.9907850434 -> 9907850434 성능 개선 X

# %%
#  1번 -> 상우기본
#  2번 162 정답 C
#  3번 117번 성능개선 X

#  4번 66번 성능개선 X
#  5번 66번,117번, 성능개선 X
#  6번 5번, 66번 성능 떨어짐 -> 5번은 정답 C(Public기준)
#  7번 19번,66번 성능개선X
#  8번 60번,66번 성능개선X

# %% [markdown]
# 19번 변경 O
# 60번 변경 O
# 117번 변경 X
#
# 19번 변경 O
# 60번 변경 X
# 117번 변경 O
#
# 19번 변경 X
# 60번 변경 O
# 117번 변경 O
#
# 19번 변경 O
# 60번 변경 O
# 117번 변경 O

# %% [markdown]
# ## Submission_09

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
sixth = Best_sub.copy()

# %%
sixth['class'].compare(submit_copy['GaussianProcessClassifier'])
# Out:
#     self other
# 19     C     B
# 60     A     C
# 66     C     B
# 117    C     B
# 119    C     B

# %%
sixth['class'].compare(submit_copy['CalibratedClassifierCV'])
# Out:
#     self other
# 5      C     B
# 19     C     B
# 60     A     C
# 66     C     B
# 126    B     C
# 162    C     B

# %%
sixth['class_01'] = sixth['class']
sixth['class_02'] = sixth['class']
sixth['GaussianProcessClassifier'] = submit_copy['GaussianProcessClassifier']
sixth['GaussianProcessClassifier_01'] = submit_copy['GaussianProcessClassifier']
sixth['CalibratedClassifierCV'] = submit_copy['CalibratedClassifierCV']
sixth['CalibratedClassifierCV_01'] = submit_copy['CalibratedClassifierCV']
sixth = sixth.iloc[:,1:]

# %%
Last_submmit_09 = pd.DataFrame(submit['id'])
Last_submmit_09['class'] = sixth.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_09.compare(Best_sub)
# Out:
#    class
#     self other
# 19     B     C
# 60     C     A
# 66     B     C

# %%
# Last_submmit_09.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_09.csv', index=False)

# %%
# 0.9907850434 -> # 0.9907850434 19,60,66번 변경 성능 개선 X

# %% [markdown]
# ## Submission_10

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
seven = Best_sub.copy()

# %%
seven['class'].compare(submit_copy['MLPClassifier'])
# Out:
#     self other
# 5      C     B
# 60     A     C
# 66     C     B
# 126    B     C

# %%
seven['class'].compare(submit_copy['LinearSVC'])
# Out:
#     self other
# 5      C     B
# 19     C     B
# 35     B     C
# 66     C     B
# 126    B     C

# %%
seven['class_01'] = seven['class']
seven['class_02'] = seven['class']
seven['MLPClassifier'] = submit_copy['MLPClassifier']
seven['MLPClassifier_01'] = submit_copy['MLPClassifier']
seven['LinearSVC'] = submit_copy['LinearSVC']
seven['LinearSVC_01'] = submit_copy['LinearSVC']
seven = seven.iloc[:,1:]

# %%
Last_submmit_10 = pd.DataFrame(submit['id'])
Last_submmit_10['class'] = seven.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_10.compare(Best_sub)
# Out:
#     class
#      self other
# 5       B     C
# 66      B     C
# 126     C     B

# %%
# Last_submmit_10.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_10.csv', index=False)

# %%
# 0.9814285714 -> 0.9814285714 5번, 66번, 126번 교체 (기존 5번, 66번 바꾼거에서 성능개선 X 126번 Private)

# %% [markdown]
# ## Submission_11

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
eight = Best_sub.copy()

# %%
eight['class'].compare(submit_copy['CatBoostClassifier'])
# Out:
#     self other
# 5      C     B
# 19     C     B
# 60     A     C
# 66     C     B
# 90     B     C
# 117    C     B

# %%
eight['class'].compare(submit_copy['RidgeClassifier'])
# Out:
#     self other
# 5      C     B
# 19     C     B
# 66     C     B
# 90     B     C
# 126    B     C
# 162    C     B

# %%
eight['class_01'] = eight['class']
eight['class_02'] = eight['class']
eight['CatBoostClassifier'] = submit_copy['CatBoostClassifier']
eight['CatBoostClassifier_01'] = submit_copy['CatBoostClassifier']
eight['RidgeClassifier'] = submit_copy['RidgeClassifier']
eight['RidgeClassifier_01'] = submit_copy['RidgeClassifier']
eight = eight.iloc[:,1:]

# %%
Last_submmit_11 = pd.DataFrame(submit['id'])
Last_submmit_11['class'] = eight.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_11.compare(Best_sub)
# Out:
#    class
#     self other
# 5      B     C
# 19     B     C
# 66     B     C
# 90     C     B

# %%
# Last_submmit_11.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_11.csv', index=False)

# %%
# 0.9814285714 -> 0.9814285714 5번, 66번, 126번 교체 (기존 5번, 66번 바꾼거에서 성능개선 X 126번 Private)

# %% [markdown]
# ## Submission_12

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
nine = Best_sub.copy()

# %%
nine['class'].compare(submit_copy['LabelSpreading'])
# Out:
#     self other
# 12     B     C
# 19     C     B
# 60     A     C
# 66     C     B
# 84     B     C
# 90     B     C
# 117    C     B
# 119    C     B
# 167    B     C

# %%
nine['class'].compare(submit_copy['KNeighborsClassifier'])
# Out:
#     self other
# 5      C     B
# 19     C     B
# 60     A     C
# 66     C     B
# 117    C     B
# 119    C     B
# 162    C     B

# %%
nine['class_01'] = nine['class']
nine['class_02'] = nine['class']
nine['LabelSpreading'] = submit_copy['LabelSpreading']
nine['LabelSpreading_01'] = submit_copy['LabelSpreading']
nine['KNeighborsClassifier'] = submit_copy['KNeighborsClassifier']
nine['KNeighborsClassifier_01'] = submit_copy['KNeighborsClassifier']
nine = nine.iloc[:,1:]

# %%
Last_submmit_12 = pd.DataFrame(submit['id'])
Last_submmit_12['class'] = nine.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_12.compare(Best_sub)
# Out:
#     class
#      self other
# 19      B     C
# 60      C     A
# 66      B     C
# 117     B     C
# 119     B     C

# %%
# Last_submmit_12.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_12.csv', index=False)

# %%
# 0.9907850434 -> 0.9814285714 19번,60번,66번,117번,119번 변경 -> 성능떨어짐 (119번 정답 C)

# %% [markdown]
# ## Submission_13

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
ten = Best_sub.copy()

# %%
ten['class'].compare(submit_copy['AdaBoostClassifier'])
# Out:
#     self other
# 12     B     C
# 29     B     C
# 35     B     C
# 39     C     B
# 48     B     C
# 66     C     B
# 83     B     C
# 90     B     C
# 107    B     C
# 110    C     B
# 117    C     B
# 132    B     C

# %%
ten['class'].compare(submit_copy['LinearSVC'])
# Out:
#     self other
# 5      C     B
# 19     C     B
# 35     B     C
# 66     C     B
# 126    B     C

# %%
ten['class_01'] = ten['class']
ten['class_02'] = ten['class']
ten['AdaBoostClassifier'] = submit_copy['AdaBoostClassifier']
ten['AdaBoostClassifier_01'] = submit_copy['AdaBoostClassifier']
ten['LinearSVC'] = submit_copy['LinearSVC']
ten['LinearSVC_01'] = submit_copy['LinearSVC']
ten = ten.iloc[:,1:]

# %%
Last_submmit_13 = pd.DataFrame(submit['id'])
Last_submmit_13['class'] = ten.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_13.compare(Best_sub)
# Out:
#    class
#     self other
# 35     C     B
# 66     B     C

# %%
# Last_submmit_13.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_13.csv', index=False)

# %%
# 0.9907850434 -> 0.9817 66번,35번 바꿈 성능 떨어짐 -> 35번 정답 : B

# %% [markdown]
# ## Submission_14

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
eleven = Best_sub.copy()

# %%
eleven['class'].compare(submit_copy['Perceptron'])
# Out:
#     self other
# 19     C     B
# 58     B     C
# 60     A     C
# 66     C     B
# 126    B     C
# 145    B     C

# %%
eleven['class'].compare(submit_copy['HistGradientBoostingClassifier'])
# Out:
#     self other
# 5      C     B
# 19     C     B
# 66     C     B
# 145    B     C

# %%
eleven['class_01'] = eleven['class']
eleven['class_02'] = eleven['class']
eleven['Perceptron'] = submit_copy['Perceptron']
eleven['Perceptron_01'] = submit_copy['Perceptron']
eleven['HistGradientBoostingClassifier'] = submit_copy['HistGradientBoostingClassifier']
eleven['HistGradientBoostingClassifier_01'] = submit_copy['HistGradientBoostingClassifier']
eleven = eleven.iloc[:,1:]

# %%
Last_submmit_14 = pd.DataFrame(submit['id'])
Last_submmit_14['class'] = eleven.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_14.compare(Best_sub)
# Out:
#     class
#      self other
# 19      B     C
# 66      B     C
# 145     C     B

# %%
# Last_submmit_14.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_14.csv', index=False)

# %%
# 0.9907850434 -> 0.9907850434이고 19,66,145번 바꿈 145번은 Prviate피처

# %% [markdown]
# ## Last_submmit_02_02

# %%
# Last_submmit_02.loc[35, 'class'] = 'A'

# %%
# Last_submmit_02.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02_02.csv', index=False)

# %%
# 02_02 : Public에서 틀린값이 C인데 B로예측한걸알수있음
#  1 -> 상우기본
#  2 162 정답 C
#  3 117번 성능개선 X
#  4 66번 성능개선 X
#  5 66번,117번, 성능개선 X
#  6 5번, 66번 성능 떨어짐 -> 5번은 정답 C(Public기준)
#  7 19번,66번 성능개선X
#  8 60번,66번 성능개선X
#  9 19,60,66번 성능개선 X 
#  10 5번, 66번, 126번 교체 (기존 5번, 66번 바꾼거에서 성능개선 X 126번 Private)
#  11 126번 검증
#  12 19번,60번,66번,117번,119번 변경 -> 성능떨어짐 (119번 정답 C)
#  13 66번,35번 바꿈 성능 떨어짐 -> 35번 정답 : B
#  14 19, 66, 145번 바꿈 성능개선 X

#  126번무조건 바꾸기

# %% [markdown]
# 162번 정답 C
# 117번은 Private 데이터
# 126 Private데이터
# 90 Private데이터
# 60번 Private데이터
# 19번 Private데이터
# 119 정답 C
# 5번 정답 C
# 35번 정답 B
# 145번 Private데이터

# %% [markdown]
# ## Submission_02_03

# %%
all_models_score_02 = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/models_score_26_san_smote.csv')
all_models_score_03 = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/models_score_74_san_smote.csv')
submit_02 = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/all_submit_26_san_smote.csv')
submit_03 = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/all_submit_74_san_smote.csv')
submit_02 = submit_02.iloc[:,1:]
submit_03 = submit_03.iloc[:,1:]
submit_02 = submit_02.replace([0,1,2],['A','B','C'])
submit_03 = submit_03.replace([0,1,2],['A','B','C'])

# %%
Fine_02_03 = pd.read_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02.csv')

# %%
Fine_02_03.loc[126,'class'] = 'A'

# %%
Best_sub.compare(Fine_02_03)
# Out:
#     class
#      self other
# 5       C     B
# 19      C     B
# 60      A     C
# 66      C     B
# 117     C     B
# 126     B     A
# 162     C     B

# %%
# Fine_02_03.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02_03.csv', index=False)

# %% [markdown]
# ## Submission_02_04

# %%
Fine_02_04 = pd.read_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02.csv')

# %%
Fine_02_04.loc[90,'class'] = 'A'

# %%
Best_sub.compare(Fine_02_04)
# Out:
#     class
#      self other
# 5       C     B
# 19      C     B
# 60      A     C
# 66      C     B
# 90      B     A
# 117     C     B
# 162     C     B

# %%
# Fine_02_04.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02_04.csv', index=False)

# %% [markdown]
# ## Submission_15

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
submit_copy.loc[84]
# Out:
# AdaBoostClassifier                B
# BaggingClassifier                 B
# DecisionTreeClassifier            C
# DummyClassifier                   C
# ExtraTreeClassifier               B
# ExtraTreesClassifier              C
# GaussianProcessClassifier         B
# GradientBoostingClassifier        B
# HistGradientBoostingClassifier    B
# LinearSVC                         B
# MLPClassifier                     B
# NuSVC                             B
# PassiveAggressiveClassifier       B
# Perceptron                        B
# RandomForestClassifier            B
# RidgeClassifier                   B
# SGDClassifier                     B
# SVC                               B
# LogisticRegression                B
# LogisticRegressionCV              B
# BernoulliNB                       B
# CalibratedClassifierCV            B
# GaussianNB                        B
# KNeighborsClassifier              B
# LabelPropagation                  C
# LabelSpreading                    C
# ...

# %%
twelve = Best_sub.copy()

# %%
twelve['class'].compare(submit_copy['DecisionTreeClassifier'])
# Out:
#     self other
# 5      C     B
# 21     B     C
# 29     B     C
# 35     B     C
# 66     C     B
# 84     B     C
# 90     B     C
# 117    C     B
# 122    B     C

# %%
twelve['class'].compare(submit_copy['LabelPropagation'])
# Out:
#     self other
# 12     B     C
# 19     C     B
# 60     A     C
# 66     C     B
# 84     B     C
# 90     B     C
# 117    C     B
# 119    C     B
# 167    B     C

# %%
twelve['class_01'] = twelve['class']
twelve['class_02'] = twelve['class']
twelve['DecisionTreeClassifier'] = submit_copy['DecisionTreeClassifier']
twelve['DecisionTreeClassifier_01'] = submit_copy['DecisionTreeClassifier']
twelve['LabelPropagation'] = submit_copy['LabelPropagation']
twelve['LabelPropagation_01'] = submit_copy['LabelPropagation']
twelve = twelve.iloc[:,1:]

# %%
Last_submmit_15 = pd.DataFrame(submit['id'])
Last_submmit_15['class'] = twelve.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_15.compare(Best_sub)
# Out:
#     class
#      self other
# 66      B     C
# 84      C     B
# 90      C     B
# 117     B     C

# %%
# Last_submmit_15.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_15.csv', index=False)

# %%
# 0.9907850434 -> 0.981703026 -> 84번 정답은 B

# %% [markdown]
# ## Submission_16

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
submit_copy.loc[21]
# Out:
# AdaBoostClassifier                B
# BaggingClassifier                 C
# DecisionTreeClassifier            C
# DummyClassifier                   B
# ExtraTreeClassifier               B
# ExtraTreesClassifier              C
# GaussianProcessClassifier         B
# GradientBoostingClassifier        C
# HistGradientBoostingClassifier    B
# LinearSVC                         B
# MLPClassifier                     B
# NuSVC                             B
# PassiveAggressiveClassifier       B
# Perceptron                        B
# RandomForestClassifier            C
# RidgeClassifier                   B
# SGDClassifier                     B
# SVC                               B
# LogisticRegression                B
# LogisticRegressionCV              B
# BernoulliNB                       B
# CalibratedClassifierCV            B
# GaussianNB                        B
# KNeighborsClassifier              B
# LabelPropagation                  B
# LabelSpreading                    B
# ...

# %%
thirteen = Best_sub.copy()

# %%
thirteen['class'].compare(submit_copy['BaggingClassifier'])
# Out:
#     self other
# 5      C     B
# 19     C     B
# 21     B     C
# 66     C     B
# 83     B     C
# 117    C     B
# 162    C     B

# %%
thirteen['class'].compare(submit_copy['DecisionTreeClassifier'])
# Out:
#     self other
# 5      C     B
# 21     B     C
# 29     B     C
# 35     B     C
# 66     C     B
# 84     B     C
# 90     B     C
# 117    C     B
# 122    B     C

# %%
thirteen['class_01'] = thirteen['class']
thirteen['class_02'] = thirteen['class']
thirteen['BaggingClassifier'] = submit_copy['BaggingClassifier']
thirteen['BaggingClassifier_01'] = submit_copy['BaggingClassifier']
thirteen['DecisionTreeClassifier'] = submit_copy['DecisionTreeClassifier']
thirteen['DecisionTreeClassifier_01'] = submit_copy['DecisionTreeClassifier']
thirteen = thirteen.iloc[:,1:]

# %%
Last_submmit_16 = pd.DataFrame(submit['id'])
Last_submmit_16['class'] = thirteen.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_16.compare(Best_sub)
# Out:
#     class
#      self other
# 5       B     C
# 21      C     B
# 66      B     C
# 117     B     C

# %%
# Last_submmit_16.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_16.csv', index=False)

# %%
# 0.981703026 -> 0.97235 -> 21번 정답은 B

# %% [markdown]
# ## Submission_17

# %%
submit_copy.columns
# Out:
# Index(['AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier',
#        'DummyClassifier', 'ExtraTreeClassifier', 'ExtraTreesClassifier',
#        'GaussianProcessClassifier', 'GradientBoostingClassifier',
#        'HistGradientBoostingClassifier', 'LinearSVC', 'MLPClassifier', 'NuSVC',
#        'PassiveAggressiveClassifier', 'Perceptron', 'RandomForestClassifier',
#        'RidgeClassifier', 'SGDClassifier', 'SVC', 'LogisticRegression',
#        'LogisticRegressionCV', 'BernoulliNB', 'CalibratedClassifierCV',
#        'GaussianNB', 'KNeighborsClassifier', 'LabelPropagation',
#        'LabelSpreading', 'LinearDiscriminantAnalysis', 'NearestCentroid',
#        'QuadraticDiscriminantAnalysis', 'RidgeClassifierCV', 'LGBMClassifier',
#        'XGBClassifier', 'CatBoostClassifier'],
#       dtype='object')

# %%
submit_copy.loc[12]
# Out:
# AdaBoostClassifier                C
# BaggingClassifier                 B
# DecisionTreeClassifier            B
# DummyClassifier                   B
# ExtraTreeClassifier               C
# ExtraTreesClassifier              B
# GaussianProcessClassifier         B
# GradientBoostingClassifier        B
# HistGradientBoostingClassifier    B
# LinearSVC                         B
# MLPClassifier                     B
# NuSVC                             B
# PassiveAggressiveClassifier       B
# Perceptron                        B
# RandomForestClassifier            B
# RidgeClassifier                   B
# SGDClassifier                     B
# SVC                               B
# LogisticRegression                B
# LogisticRegressionCV              B
# BernoulliNB                       C
# CalibratedClassifierCV            B
# GaussianNB                        B
# KNeighborsClassifier              B
# LabelPropagation                  C
# LabelSpreading                    C
# ...

# %%
fourteen = Best_sub.copy()

# %%
fourteen['class'].compare(submit_copy['LabelSpreading'])
# Out:
#     self other
# 12     B     C
# 19     C     B
# 60     A     C
# 66     C     B
# 84     B     C
# 90     B     C
# 117    C     B
# 119    C     B
# 167    B     C

# %%
fourteen['class_01'] = fourteen['class']
fourteen['class_02'] = fourteen['class']
fourteen['AdaBoostClassifier'] = submit_copy['AdaBoostClassifier']
fourteen['AdaBoostClassifier_01'] = submit_copy['AdaBoostClassifier']
fourteen['LabelSpreading'] = submit_copy['LabelSpreading']
fourteen['LabelSpreading_01'] = submit_copy['LabelSpreading']
fourteen = fourteen.iloc[:,1:]

# %%
Last_submmit_17 = pd.DataFrame(submit['id'])
Last_submmit_17['class'] = fourteen.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_17.compare(Best_sub)
# Out:
#     class
#      self other
# 12      C     B
# 66      B     C
# 90      C     B
# 117     B     C

# %%
# Last_submmit_17.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_17.csv', index=False)

# %%
# 0.9907850434 -> 0.9907850434 -> 12번은 Private데이터

# %% [markdown]
# ## Submission_02_05

# %%
Fine_02_05 = pd.read_csv('/content/drive/MyDrive/유전체공모전/submissions/automl_02.csv')

# %%
Best_sub.compare(Fine_02_05)
# Out:
#     class
#      self other
# 3       C     B
# 5       C     B
# 66      C     B
# 119     C     B

# %%
Fine_02_05.loc[5,'class'] = 'A'

# %%
Best_sub.compare(Fine_02_05)
# Out:
#     class
#      self other
# 3       C     B
# 5       C     A
# 66      C     B
# 119     C     B

# %%
# Fine_02_05.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02_05.csv', index=False)

# %%
# 0.9622367466 -> 0.9593 5번 정답은 C

# %% [markdown]
# ## Submission_02_06

# %%
Fine_02_06 = pd.read_csv('/content/drive/MyDrive/유전체공모전/submissions/automl_02.csv')
Fine_02_07 = Fine_02_06.copy()
Fine_02_08 = Fine_02_06.copy()
Fine_02_09 = Fine_02_06.copy()
Fine_02_10 = Fine_02_06.copy()
Fine_02_11 = Fine_02_06.copy()

# %%
Best_sub.compare(Fine_02_06)
# Out:
#     class
#      self other
# 3       C     B
# 5       C     B
# 66      C     B
# 119     C     B

# %%
Fine_02_06.loc[162,'class'] = 'A'
Fine_02_07.loc[49,'class'] = 'A'
Fine_02_08.loc[110,'class'] = 'A'
Fine_02_09.loc[64,'class'] = 'A'
Fine_02_10.loc[92,'class'] = 'A'
Fine_02_11.loc[3,'class'] = 'A'

# %%
Best_sub.compare(Fine_02_11)
# Out:
#     class
#      self other
# 3       C     A
# 5       C     B
# 66      C     B
# 119     C     B

# %%
# Fine_02_06.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02_06.csv', index=False)
# Fine_02_07.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02_07.csv', index=False)
# Fine_02_08.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02_08.csv', index=False)
# Fine_02_09.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02_09.csv', index=False)
# Fine_02_10.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02_10.csv', index=False)
# Fine_02_11.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_02_11.csv', index=False)

# %%
# 162,49,110,64,92,3 바꿈 0.9622367466 -> 0.9494209576, 마지막 3번만 0.95934

# %% [markdown]
# 162번 정답 C
# 117번은 Private 데이터 (확실)
# 126 Private데이터 (확실)
# 90 Private데이터 (확실)
# 60번 Private데이터(확실)
# 19번 Private데이터 (확실)
# 119 정답 C
# 5번 정답 C
# 35번 정답 B
# 21번 정답 B
# 12번 Private데이터(확실)
# 84번 정답 B
# 145번 Private데이터(확실)
# 49 A는 아님
# 110 A는 아님
# 64 A는 아님
# 92 A는 아님
# 3 A는 아님

# %%
all_models_score_02 = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/models_score_26_san_smote.csv')
all_models_score_03 = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/models_score_74_san_smote.csv')
submit_02 = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/all_submit_26_san_smote.csv')
submit_03 = pd.read_csv('/content/drive/MyDrive/유전체공모전/data/all_submit_74_san_smote.csv')
submit_02 = submit_02.iloc[:,1:]
submit_03 = submit_03.iloc[:,1:]
submit_02 = submit_02.replace([0,1,2],['A','B','C'])
submit_03 = submit_03.replace([0,1,2],['A','B','C'])

# %% [markdown]
# ## Submission_18

# %%
submit_02.loc[103]
# Out:
# AdaBoostClassifier                B
# BaggingClassifier                 B
# DecisionTreeClassifier            B
# DummyClassifier                   A
# ExtraTreeClassifier               B
# ExtraTreesClassifier              C
# GaussianProcessClassifier         C
# GradientBoostingClassifier        B
# HistGradientBoostingClassifier    B
# LinearSVC                         C
# MLPClassifier                     C
# NuSVC                             C
# PassiveAggressiveClassifier       B
# Perceptron                        B
# RandomForestClassifier            C
# RidgeClassifier                   C
# SGDClassifier                     B
# SVC                               C
# LogisticRegression                C
# LogisticRegressionCV              C
# BernoulliNB                       C
# CalibratedClassifierCV            C
# GaussianNB                        B
# KNeighborsClassifier              C
# LabelPropagation                  C
# LabelSpreading                    C
# ...

# %%
fifteen = Best_sub.copy()

# %%
fifteen['class'].compare(submit_02['LGBMClassifier'])
# Out:
#     self other
# 5      C     B
# 66     C     B
# 103    C     B

# %%
fifteen['class'].compare(submit_02['BaggingClassifier'])
# Out:
#     self other
# 56     C     B
# 66     C     B
# 101    B     C
# 103    C     B
# 126    B     C
# 162    C     B

# %%
fifteen['class_01'] = fifteen['class']
fifteen['class_02'] = fifteen['class']
fifteen['LGBMClassifier'] = submit_02['LGBMClassifier']
fifteen['LGBMClassifier_01'] = submit_02['LGBMClassifier']
fifteen['BaggingClassifier'] = submit_02['BaggingClassifier']
fifteen['BaggingClassifier_01'] = submit_02['BaggingClassifier']
fifteen = fifteen.iloc[:,1:]

# %%
Last_submmit_18 = pd.DataFrame(submit['id'])
Last_submmit_18['class'] = fifteen.agg(pd.Series.mode,axis=1)

# %%
Last_submmit_18.compare(Best_sub)
# Out:
#     class
#      self other
# 66      B     C
# 103     B     C

# %%
# Last_submmit_18.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_18.csv', index=False)

# %% [markdown]
# ## Submission_19

# %%
sub_18 = pd.read_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_18.csv')

# %%
sub_18.loc[126, 'class'] = 'C'

# %%
# sub_18.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_19.csv', index=False)

# %%
sangwoo = pd.read_csv('/content/drive/MyDrive/유전체공모전/submissions/baseline12.csv')

# %%
sub_18 = pd.read_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_18.csv')

# %%
sub_19 = pd.read_csv('/content/drive/MyDrive/유전체공모전/submissions/FINAL_2nd.csv')

# %%
sub_18
# Out:
#            id class
# 0    TEST_000     A
# 1    TEST_001     B
# 2    TEST_002     C
# 3    TEST_003     C
# 4    TEST_004     A
# ..        ...   ...
# 170  TEST_170     B
# 171  TEST_171     C
# 172  TEST_172     C
# 173  TEST_173     B
# 174  TEST_174     B
#
# [175 rows x 2 columns]

# %%
sub_19.compare(sangwoo)
# Out:
#     class
#      self other
# 66      B     C
# 103     B     C
# 117     B     C

# %%
sub_19.loc[19, 'class'] = 'B'

# %%
# sub_19.to_csv('/content/drive/MyDrive/유전체공모전/submissions/Fine_20.csv', index=False)
